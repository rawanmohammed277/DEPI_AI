# %% [markdown]
# # **Function**

# %%
def func1():
    print("hello from func1")

# %%
func1()
# Out:
# hello from func1

# %%
def get_info(name, age):
    print(f"my name is {name} and my age is {age}")

# %%
get_info("rawan", 20)
# Out:
# my name is rawan and my age is 20

# %%
def get_info(name: str, age: int):
    '''  function to get name and age of a person
    
    Arguments:
        parameter_1 >> The name of the person
        type_parameter_1 >> name (str)
        
        parameter_2 >> The age of the person
        type_parameter_2 >> age (int)
        
        returns >> the name and age of the person
        type_returns >> str, int

    '''
    return f"my name is {name} and my age is {age}"

# %%
get_info("rawan", 20)
# Out:
# 'my name is rawan and my age is 20'

# %%
get_info(age=20, name='rawan')
# Out:
# 'my name is rawan and my age is 20'

# %% [markdown]
# ### **Default Parameter**

# %%
def user_info(name='rawan', age=20):
    '''  function to get name, age and country of a person
    
    Arguments:
        parameter_1 >> The name of the person
        type_parameter_1 >> name (str)
        
        parameter_2 >> The age of the person
        type_parameter_2 >> age (int)

        
        returns >> the name and age of the person
        type_returns >> str, int

    '''
    return f"my name is {name} and my age is {age}"

# %%
user_info()
# Out:
# 'my name is rawan and my age is 20'

# %%
def main():

    def add(x: float, y: float) -> float:
        '''  function to add two numbers
    
        Arguments:
        parameter_1 >> The first number
        type_parameter_1 >> x (float)
        
        parameter_2 >> The second number
        type_parameter_2 >> y (float)

        
        returns >> the sum of the two numbers
        type_returns >> float

    '''
        return x + y


    def subtract(x: float, y: float) -> float:
        '''  function to subtract two numbers
    
    Arguments:
        parameter_1 >> The first number
        type_parameter_1 >> x (float)
        
        parameter_2 >> The second number
        type_parameter_2 >> y (float)

        
        returns >> the difference of the two numbers
        type_returns >> float

    '''
        return x - y


    def multiply(x: float, y: float) -> float:
        '''  function to multiply two numbers
    
    Arguments:
        parameter_1 >> The first number
        type_parameter_1 >> x (float)
        
        parameter_2 >> The second number
        type_parameter_2 >> y (float)

        
        returns >> the product of the two numbers
        type_returns >> float

    '''
        return x * y

    def division(x: float, y: float) -> float:
        '''  function to divide two numbers
    
    Arguments:
        parameter_1 >> The first number
        type_parameter_1 >> x (float)
        
        parameter_2 >> The second number
        type_parameter_2 >> y (float)

        
        returns >> the quotient of the two numbers
        type_returns >> float

    '''
    
        return x / y



    print('Calculator Application')
    print('=====================================')
    print('1 >>> add ')
    print('2 >>> subtract ')
    print('3 >>> multiply ')
    print('4 >>> divide ')
    choice = input('Enter your choice (1/2/3/4): ')
    num1 = float(input('Enter first number: '))
    num2 = float(input('Enter second number: '))
    print(f'you chose {choice} and your numbers are {num1} and {num2}')
    if choice == '1':
        print(f'{num1} + {num2} = the result of addition is {add(num1, num2)}')
    elif choice == '2':
        print(f'{num1} - {num2} = the result of subtraction is {subtract(num1, num2)}')
    elif choice == '3':
        print(f'{num1} * {num2} = the result of multiplication is {multiply(num1, num2)}')
    elif choice == '4':
        print(f'{num1} / {num2} = the result of division is {division(num1, num2)}')

# %%
main()
# Out:
# Calculator Application
# ...
# 1 >>> add
# 2 >>> subtract
# 3 >>> multiply
# 4 >>> divide
# you chose 4 and your numbers are 3.0 and 6.0
# 3.0 / 6.0 = the result of division is 0.5

# %%
from calc import add
add(5, 3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from calc import add
#       2 add(5, 3)
#
# ImportError: cannot import name 'add' from 'calc' (c:\Users\New Star Computer 25\DEPI_AI\src\python\session 3\code\calc.py)

# %%
def function(*name):
    print(name)
    print(type(name))

# %%
function('rawan', 'ahmed', 'ali', 'mohamed',30,40,True,False,3.14,2.71,1.618,0.57721,1.41421,2.23607,3.16228,4.47214,5.38516,6.32456,7.07107,8.06226,9.05539,10.04988)
# Out:
# ('rawan', 'ahmed', 'ali', 'mohamed', 30, 40, True, False, 3.14, 2.71, 1.618, 0.57721, 1.41421, 2.23607, 3.16228, 4.47214, 5.38516, 6.32456, 7.07107, 8.06226, 9.05539, 10.04988)
# <class 'tuple'>
