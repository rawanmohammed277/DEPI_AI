# %% [markdown]
# ### **Basics**

# %%
5+6
# Out:
# 11

# %%
x='rawan'

# %%
print("my name {0}, my age is {1}".format(x, 20))
# Out:
# my name rawan, my age is 20

# %%
name="rawan"
my_age=20
course_name="AI & Data Science"

# %%
print("my name is {0}, and my age is {1} years old, iam engaged in learning {2} ".format(name,my_age, course_name))
# Out:
# my name is rawan, and my age is 20 years old, iam engaged in learning AI & Data Science

# %%
print(f"my name is {name}, and my age is {my_age} years old, iam engaged in learning {course_name} ")
# Out:
# my name is rawan, and my age is 20 years old, iam engaged in learning AI & Data Science

# %%
name="amit learning"
print(name[5:13:1])
# Out:
# learning
