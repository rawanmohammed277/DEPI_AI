# %% [markdown]
# ### **Basics**

# %%
5+6
# Out:
# 11

# %%
x='rawan'

# %%
print("my name {0}, my age is {1}".format(x, 20))
# Out:
#   Cell In[7], line 1
#     print("my name {0}, my age is {1}".format{'rawan' ,20 } )
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
